# %% [markdown]
#     Insurance Data

# %% [markdown]
# ---
#
# # **Project: Insurance Data Analysis**
#
# ---
#
# ### **Project Description:**
#
# This project focuses on analyzing insurance data to understand the key factors influencing insurance charges and customer demographics. The dataset contains detailed information on customers, such as age, gender, body mass index (BMI), number of children, smoking status, and geographical region.
#
# By exploring these variables, we aim to:
#
# - Uncover patterns and trends that affect insurance charges.
# - Provide insights to help insurance companies refine their pricing strategies.
# - Gain a deeper understanding of customer demographics and risk factors.
#
# ---
#
# ### **Objectives:**
#
# 1. **Data Cleaning:**
#    - Manage missing values and identify any outliers to ensure a high-quality dataset for analysis.
#
# 2. **Data Visualization:**
#    - Create visualizations to explore key trends and patterns in the data, focusing on factors that may influence insurance charges (e.g., age, BMI, smoking status).
#
# 3. **Encoding and Normalization:**
#    - Prepare the data by encoding categorical variables and normalizing numerical features for further analysis and predictive modeling.
#
# ---
#
# ### **Dataset Overview:**
#
# The dataset consists of 1,338 records, including the following features:
#
# - **Age:** Age of the individual.
# - **Sex:** Gender of the individual (male/female).
# - **BMI:** Body Mass Index, a measure of body fat based on height and weight.
# - **Children:** Number of children or dependents covered by the insurance.
# - **Smoker:** Smoking status of the individual (yes/no).
# - **Region:** Geographical region (e.g., northeast, northwest, southeast, southwest).
# - **Charges:** Medical insurance costs billed to the individual.
#
# This dataset provides a foundation for analyzing the relationships between customer attributes and insurance charges.
#
# ---
#
# ### **Analysis Steps:**
#
# ⓵ **Data Cleaning:**
#    - Handle any missing values (e.g., BMI) and identify potential outliers to ensure data integrity.
#
# ⓶ **Exploratory Data Analysis:**
#    - Investigate the distribution of variables and identify trends, such as the impact of smoking status on charges or the correlation between age and BMI.
#
# ⓷ **Encoding and Normalization:**
#    - Encode categorical variables (e.g., sex, smoker status, region) and normalize numerical data (e.g., BMI, charges) to prepare for analysis.
#
# ⓸ **Answer Key Business Questions:**
#
#    ### **Business Questions:**
#
#    1. How do insurance charges differ between smokers and non-smokers?
#    2. Is there a significant difference in charges based on gender?
#    3. How does BMI affect the cost of insurance?
#    4. Which region has the highest average insurance charges?
#
# ---
#
# ### **Required Libraries:**
#
# - pandas: For data manipulation and analysis.
# - matplotlib: For data visualization.
# - seaborn: For statistical data visualization to explore trends.
# - sklearn: For encoding and normalization of features if needed.
# ---

# %% [markdown]
# # Importing libarires
#
# ❐ We start by importing the necessary libraries for data analysis and visualization :
#
# **`numpy`**
#
# - A library for numerical operations.
#
#
# **`pandas`**
#
# - A powerful library for data manipulation and analysis.
#
#
# **`seaborn`**
#
# - A library for statistical data visualization.
#
#
# **`matplotlib`**
#
# -  A library for creating static, animated, and interactive visualizations.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# # ① Loading Data from a CSV File
#
# ---
#
# ### 🧩 Goal
# Use the `pandas` library to load the Data from a CSV file into a DataFrame
#
# and then display sample rows to verify successful loading .
#
# ---
#
# ### ⚙️ Method
#
# #### Basic Steps:
#
# 1. **Specify File Path**
#    Define the path to the CSV file, e.g., `"data/hotel_bookings.csv"`.
#
# 2. **Load the Data**
#    Use `pd.read_csv()` to read the data into a DataFrame.
#
# 3. **Verify Data Load**
#    Display the first 5 rows using `head()` to confirm data loaded correctly.
#
# ---

# %%
file_path = '/content/drive/MyDrive/Data File/Data_Insurance_02.csv'

data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ---
#
# # ② Displaying Basic Information About the Data
#
# ---
#
# ### 🧩 Goal
# Gain an initial understanding of the dataset’s structure by examining column types, missing values, and basic descriptive statistics.
#
# ---
#
# ### ⚙️ Method
#
# #### Basic Steps:
#
# 1. **General Information**
#    Use `data.info()` to display basic information about the DataFrame, including data types and the count of non-null values in each column.
#
# 2. **Descriptive Statistics**
#    Use `data.describe().T` to generate descriptive statistics for numerical columns.
#
# 3. **Missing Values**
#    Use `data.isnull().sum()` to display the count of missing values in each column.
#
# 4. **Data Shape**
#    Use `data.shape` to see the number of rows and columns in the DataFrame.
#
# 5. **Column Names**
#    Use `data.columns` to display the names of the columns in the DataFrame.
#
# ---

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1335 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1335.0     30.661423      6.101038    15.9600    26.30250    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.687500     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         3
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# ---
#
# # Results
#
# ### 🧩 Data Size
# - The dataset contains **1,338 entries** across **7 columns**, enabling focused and precise analysis of factors affecting insurance costs.
#
# ### 🧩 Missing Data
# - There are **3 missing values** in the `bmi` column.
# - Addressing these missing values is essential before proceeding to advanced analysis to ensure accuracy.
#
# ### 🧩 Demographic Information
# - The data provides comprehensive demographic insights:
#   - The **average age** is approximately **39 years**, with a **standard deviation** of **14 years**.
#   - The dataset includes information on **sex**, **smoking status**, and **region**, offering a well-rounded view of the sample’s demographic composition.
#
# ### 🧩 Health-Related Information
# - The **average Body Mass Index (BMI)** is **30.66**, with values ranging from **15.96** to **53.13**.
# - This range of BMI values indicates variability in body mass, which may directly correlate with insurance charges.
# - The **average number of children** per record is around **1.09**, suggesting that many individuals in the sample are either single or have one child.
#
# ### 🧩 Insurance Charges
# - The **average insurance cost** is approximately **13,270.42**, with a range from a minimum of **1,121.87** to a maximum of **63,770.43**.
# - This significant variation in charges suggests that factors such as **age**, **BMI**, **smoking status**, and **region** may greatly influence the cost of insurance.
#
# ---

# %% [markdown]
# ---
#
# # ③ Handling Missing Values
#
# ###❐   Displaying Missing Values
#
# This shows the percentage of missing values in each column.
#
# To identify the columns that contain missing values, use the code:

# %%
missing_values = data.isnull().sum()
missing_columns = missing_values[missing_values > 0]

# %%
missing_columns
# Out:
# bmi    3
# dtype: int64

# %% [markdown]
# ###❐  Handling Missing Values

# %%
data = data.dropna(subset=['bmi'])

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1335 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ## Results
#
#
# After running this code, we should see a result where all columns have a count of ( **0** ) missing values.
#
# This confirms that the dataset is now free of any missing values

# %% [markdown]
# ---
#
# # Dividing the Data into Two Sections
#
# ### 📊 **Numerical Data**
#
#
# ### 🗂️ **Categorical Data**
#
# ---

# %% [markdown]
# ### 📊 **Numerical Data**
# - Creates a new DataFrame containing only columns with numerical values.
# - This subset is particularly useful for operations like **normalization** and **statistical analysis**.

# %%
num = data.select_dtypes(include=['int64', 'float64'])

# %%
num
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1335 rows x 4 columns]

# %% [markdown]
# ### 🗂️ **Categorical Data**
# - Creates a new DataFrame that includes only columns representing categorical values.
# - These categorical values will later be **encoded** to make them suitable for further analysis.

# %%
for i in data.columns :
  x = data[i].value_counts()
  print (f'{i} = {len(x)}')
# Out:
# age = 47
# sex = 2
# bmi = 548
# children = 6
# smoker = 2
# region = 4
# charges = 1334

# %%
cat = data[['sex' , 'children' , 'smoker' , 'region' ]]

# %%
cat
# Out:
#          sex  children smoker     region
# 0     female         0    yes  southwest
# 1       male         1     no  southeast
# 2       male         3     no  southeast
# 3       male         0     no  northwest
# 4       male         0     no  northwest
# ...      ...       ...    ...        ...
# 1333    male         3     no  northwest
# 1334  female         0     no  northeast
# 1335  female         0     no  southeast
# 1336  female         0     no  southwest
# 1337  female         0    yes  northwest
#
# [1335 rows x 4 columns]

# %% [markdown]
# ---
#
# # Data Visualization
#
# ### 📊 **Section 1: Numerical Data**
#
# In this step, we focus on visualizing the **numerical data** to understand relationships and patterns between variables. Visualization is a powerful tool to uncover trends in the data, helping us make informed, data-driven decisions.
#
# #### Key Objectives:
#
# - **Identify Patterns**: Visualization can reveal patterns and relationships that may be significant for our analysis.
# - **Highlight Correlations**: By examining correlations, we can identify variables that may have an impact on our final results.

# %% [markdown]
# ---
#
# ## **🔻 Correlation Matrix & Heatmap**
#
# To evaluate the relationships between different numerical variables, we compute a **correlation matrix**. This matrix gives insights into the strength and direction of relationships among variables, identifying:
#
# - **Strong positive correlation**: Values close to **+1**
# - **Strong negative correlation**: Values close to **-1**
# - **No linear correlation**: Values around **0**

# %%
Correlation = num.corr()

# %%
Correlation
# Out:
#                age       bmi  children   charges
# age       1.000000  0.108005  0.043262  0.299101
# bmi       0.108005  1.000000  0.013074  0.198294
# children  0.043262  0.013074  1.000000  0.067119
# charges   0.299101  0.198294  0.067119  1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(Correlation , annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ---
#
# # Correlation Matrix and Heatmap Documentation
#
#
# The **`correlation matrix`** shows the relationships between the main variables in the dataset:
#
# [ **age** , **BMI** , **children** , **charges** ]
#
# Each cell represents a correlation coefficient, which indicates how strongly two variables are related.
#
# ---
#
# ### 🔑 **Key Findings:**
#
# 1. **Age and Charges**:
#    - Correlation: **0.3** (weak positive relationship)
#    - As **age** increases, **charges** tend to increase slightly.
#
# 2. **BMI and Charges**:
#    - Correlation: **0.2** (weak positive relationship)
#    - Higher **BMI** is weakly associated with higher **charges**.
#
# 3. **Children and Charges**:
#    - Correlation: **0.067** (very weak positive relationship)
#    - The number of **children** has almost no impact on **charges**.
#
# 4. **Charges with Itself**:
#    - The correlation of **charges** with itself is **1**, which is expected.
#
# ---
#
# ### 📌 **Conclusion:**
#
# The data shows weak correlations between **age**, **BMI**, **children**, and **charges**
#
# with the strongest relationship being between **age** and **charges**.
#
# However, these variables do not strongly predict **charges** on their own.
#
# ---

# %% [markdown]
# ---
#
# ## 🔍 **Visualization Steps**

# %% [markdown]
# ---
#
# ### Dividing the **" Smoker "** Target into Two Groups: **Smokers** and **Non-smokers**
#
# Before proceeding with **data visualization** of numerical data
#
# it's important to first divide the **"smoker"** target variable into two distinct groups for easier analysis.
#
# ---
#
# #### 1. **Purpose of the Division**
# The goal is to split the **"smoker"** category into two groups:
# - **Smokers**: Individuals who smoke.
# - **Non-smokers**: Individuals who do not smoke.
#
# ---
#
# #### 2. **Reason for the Division**
# Dividing the data into smokers and non-smokers helps:
# - Simplify analysis and visualization.
# - Allow clearer comparisons of numerical variables (e.g., age, income) between the two groups.
#
# ---
#
# #### 3. **How the Division is Done**
# - **Smokers**: Individuals with a **"Yes"** in the **smoker** column.
# - **Non-smokers**: Individuals with a **"No"** in the **smoker** column.
#
# ---

# %%
Smokers = data[(data['smoker']=='yes')]

# %%
Smokers
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# ...   ...     ...     ...       ...    ...        ...          ...
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [274 rows x 7 columns]

# %%
Non_smokers = data[(data['smoker']=='no')]

# %%
Non_smokers
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
#
# [1061 rows x 7 columns]

# %% [markdown]
# ##1. **Histogram for Numerical Columns with Target (smoker)**
#    - Plotting histograms to compare numerical data distributions between smokers and non-smokers.

# %%
sns.histplot(Smokers['age'] , kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(Non_smokers['age'] , kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ---
#
# ### 📍 Age Analysis Results: Smokers
#
#     Based on the analysis of the age distribution of smokers, the following conclusions can be made:
#
# - The **most common age range** among smokers is between **20 and 30 years old**
#
#  indicating that smoking is more prevalent among younger individuals.
#
#
# - **Unimodal distribution**: The age distribution of smokers shows a clear peak around **25 years old**
#
#  suggesting that most individuals begin smoking at this stage in their lives.
#
# ### 📍 Age Analysis Results: Non-smokers
#
#     For non-smokers, the age analysis revealed the following:
#
# - The **most common age range** among non-smokers is between **40 and 50 years old**
#
#  suggesting that non-smoking individuals tend to be in middle to older age groups.
#
# - **Normal distribution**: The age distribution for non-smokers appears to be nearly **bell-shaped**
#
#  with a peak around **50 years old**, reflecting that non-smoking habits are more prevalent among individuals in this age range.
#
# ---

# %%
sns.histplot(Smokers['charges'] , kde = True)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.histplot(Non_smokers['charges'] , kde = True)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %% [markdown]
# ---
#
# ### 📍 Charges Analysis Results: Smokers
#
#     Based on the analysis of the distribution of medical charges for smokers, the following conclusions can be made:
#
# - **Right-skewed distribution**: The charges for smokers are right-skewed, meaning that while most individuals have lower charges, a smaller group faces significantly higher charges.
#
# - **Higher medical costs**: Smokers tend to incur higher medical charges on average compared to non-smokers, with a concentration of charges around **40,000**.
#
# ---
#
# ### 📍 Charges Analysis Results: Non-smokers
#
#     For non-smokers, the charges distribution revealed the following:
#
# - **Right-skewed distribution**: Similar to smokers, non-smokers also show a right-skewed distribution, where most individuals have lower charges, while a smaller group faces higher charges.
#
# - **Lower medical costs**: Non-smokers tend to have lower medical charges on average, with fewer individuals incurring significantly high costs.
#
# ---
#
# ### 📍 Key Takeaways
#
# - **Comparison between Smokers and Non-smokers**: Smokers generally face higher medical charges compared to non-smokers, with charges concentrated in higher ranges.
#
# - **Risk of High Charges**: The right-skewed nature of both distributions indicates that, while most individuals have moderate charges, there is a significant risk of very high charges for a smaller group in both populations, particularly among smokers.
#
# ---

# %%
sns.histplot(Smokers['bmi'] , kde = True)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(Non_smokers['bmi'] , kde = True)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %% [markdown]
# ---
#
# ### 📍 BMI Analysis Results: Smokers
#
# - **Distribution**: The BMI distribution for smokers is **bell-shaped**, suggesting a **normal distribution**.
#
# - **Most Common BMI**: The majority of smokers have a BMI between **25 and 35**, with the peak around the average.
#
# - **Symmetry**: The distribution is roughly **symmetric**, indicating a balanced spread of BMI values around the center.
#
# ---
#
# ### 📍 BMI Analysis Results: Non-smokers
#
# - **Distribution**: Similar to smokers, the BMI distribution for non-smokers is **bell-shaped**, indicating a **normal distribution**.
#
# - **Most Common BMI**: The most common BMI for non-smokers is around **30**.
#
# - **Symmetry**: The distribution is also **symmetric**, with a balanced spread of BMI values.
#
# ---
#
# ### 📍 Key Takeaways
#
# - **Comparison**: Both smokers and non-smokers show a **normal distribution** of BMI values, with smokers having a peak between **25 and 35** and non-smokers around **30**.
#
# - **General Health**: Both groups have a majority with BMI values within a relatively healthy range, suggesting **no extreme outliers** in either group.
#
# ---

# %% [markdown]
# ##2. **Scatter Plot for Numerical Columns with Target 'smoker'**
#    - Plotting scatter plots to observe any distinct relationships between the numerical variables and the target (`smoker`).

# %%
sns.scatterplot(data = data , x = 'age' , y = 'charges' , hue='smoker')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %% [markdown]
# ---
#
# ### 📍 Age vs Charges Analysis: Smokers vs Non-smokers
#
# - **General Trend** :
#
#  There is a general **upward trend** in charges as age increases, for both smokers and non-smokers.
#
# - **Smokers vs Non-smokers** :
#
#  The points representing smokers are generally higher on the y-axis (indicating higher charges)
#
#  compared to non-smokers, suggesting that smokers tend to have higher insurance charges.
#
# ---
#
# ### 📍 Key Takeaways
#
# - **Age and Charges Relationship** :
#
#  Charges increase with age for both smokers and non-smokers.
#
# - **Smokers and Higher Charges** :
#
#  Smokers tend to have higher charges overall compared to non-smokers.
#
# ---

# %%
sns.scatterplot(data = data , x = 'children' , y = 'charges' , hue='smoker')
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %% [markdown]
# ---
#
# ### 📍 Number of Children vs Charges Analysis: Smokers vs Non-smokers
#
# - **General Trend** :
#
#  Individuals with **more children** tend to have **higher insurance charges**.
#
# - **Smokers vs Non-smokers** :
#
#  Smokers generally have **higher insurance charges** than non-smokers, even with the same number of children.
#
# - **Overlap between Groups** :
#
#  There is significant **overlap** between smokers and non-smokers, suggesting other factors may also influence charges.
#
# ---
#
# ### 📍 Key Takeaways
#
# - **Number of children** contributes to higher charges, but it's not the only factor.
#
# - **Smokers** have higher charges compared to non-smokers.
#
# - **Overlap between groups** indicates other influencing factors.
#
# ---

# %% [markdown]
# ##3. **Histograms for All Numerical Columns**
#    - Comparing distributions of all numerical columns between smokers and non-smokers to detect patterns and variances.

# %%
suplot_number = 421

fig = plt.figure(figsize=(15,13))
for i in num.columns:
  ax = fig.add_subplot(suplot_number)
  suplot_number+=1
  sns.histplot(Smokers[i] , kde = True)
  ax.set_title(f'Distribution of {i} for Smoker')

  ax = fig.add_subplot(suplot_number)
  suplot_number+=1
  sns.histplot(Non_smokers[i] , kde = True)
  ax.set_title(f'Distribution of {i} for Non-Smoker')

# %% [markdown]
# ---
#
# ### 📍 Analysis of Differences Between Smokers and Non-smokers Using the Histogram
#
# By using this **histogram** for each **numerical column**, we can compare it with the **target**
#
# clearly observing the differences between **smokers and non-smokers**.
#
#
# ---

# %% [markdown]
# # **Answering Business Questions Related to Data Analysis**

# %% [markdown]
# ---
# ## **Question 1 :**
#
# ### How do insurance charges differ between smokers and non-smokers?
#
# ---

# %%
sns.barplot(x='smoker', y='charges', data=data)
plt.title('Average Insurance Charges for Smokers vs Non-Smokers')
plt.show()

# %% [markdown]
# ### **Analysis of Insurance Charges for Smokers and Non-Smokers**
#
# We notice that:
# - **Smokers**: The average insurance charge is around **32,000**.
# - **Non-Smokers**: The average insurance charge is around **8,000**.
#
# The analysis indicates that insurance charges for smokers are significantly higher compared to non-smokers.
#
# **Reason**:
# Smoking is associated with higher health risks, leading insurance companies to increase charges for individuals who smoke.

# %% [markdown]
# ---
#
# ## **Question 2 :**
#
# ### Is there a significant difference in charges based on gender?
#
# ---

# %%
sns.barplot(x='sex', y='charges', data=data)
plt.title('Average Insurance Charges by Gender')
plt.show()

# %% [markdown]
# ### **Analysis of Insurance Charges by Gender**
#
# We notice that:
# - **Males**: The average insurance charge is slightly higher.
# - **Females**: The average insurance charge is slightly lower compared to males.
#
# The analysis shows a minor difference in average insurance charges between genders, but it is not statistically significant.
#
# **Reason**:
# The slight difference could be due to individual factors rather than fundamental differences between genders.

# %% [markdown]
# ---
#
# ## **Question 3 :**
#
# ### How does BMI affect the cost of insurance?
#
# ---

# %%
sns.scatterplot(x='bmi', y='charges', data=data)
plt.title('Relationship Between BMI and Insurance Charges')
plt.show()

# %% [markdown]
# ### **Analysis of the Relationship Between BMI and Insurance Charges**
#
# We notice that:
# - There is a weak **positive correlation** between **BMI** and **insurance charges**.
# - As **BMI** increases, **insurance charges** tend to increase slightly, but the relationship is not strong.
# - There are many individuals with high **BMI** who have low **insurance charges**, and vice versa.

# %% [markdown]
# ---
#
# ## **Question 4 :**
#
# ### Which region has the highest average insurance charges?
#
# ---

# %%
sns.barplot(x='region', y='charges', data=data)
plt.title('Average Insurance Charges by Region')
plt.show()

# %% [markdown]
# ### **Analysis of Insurance Charges by Region**
#
# We notice that:
# - The **Southeast** region has the highest average insurance charges, with an average of around **14,500**.
# - The other regions have average charges below **14,000**.
#
# The analysis indicates that the **Southeast** region has the highest insurance charges compared to the other regions.
#
#
# ---

# %% [markdown]
# # Handling Outliers
#
# ##**Box Plot for Numeric Columns**
#
# In this step, we create box plots for all numeric columns in the dataset to visually identify potential outliers. The box plot provides a graphical representation of the distribution of the data, highlighting the median, quartiles, and any data points that fall outside the expected range.

# %%
num.plot(kind="box", subplots=True)
plt.suptitle("Box Plot for Numeric Columns")
plt.show()

# %% [markdown]
# ---
#
# ### 📍 Note on Outliers
#
# We will not remove **outliers** from the dataset because the **sample size is relatively small**.
#
# Removing these values might impact the analysis and cause us to lose important details. Therefore
#
# we will retain all values to ensure a comprehensive analysis.
#
# ---

# %% [markdown]
# ---
#
# # Data Visualization
#
# ### 🗂️ **Section 2: Categorical Data**
#
# In this stage, we will visualize categorical data to understand the distribution of different categories and their relationships with other variables.
#
# This helps reveal patterns among categories and highlights potential connections, providing a comprehensive understanding of the data.
#
# ---
#
# #### 🎯 **Objectives of Categorical Data Analysis**
#
# - **Understand Category Distribution** : Visualization offers insight into the distribution of data across specific categories, like smoking status, number of children, etc.
#
# - **Identify Patterns and Relationships** : Visualization helps identify significant associations between categories, which may influence our final analysis results.
#
# ---

# %% [markdown]
# ## 🔍 **Visualization Steps**

# %% [markdown]
# 1. **Plotting a Pie Chart for Categorical Data**
#
# - A pie chart helps illustrate the proportions of different categories
#
#  such as the percentage of smokers versus non-smokers in the dataset.

# %%
for i in cat.columns :
 x = data[i].value_counts()
 plt.figure(figsize=(6,4))
 plt.pie(x , labels=x.index , autopct = '%1.1f%%' ,wedgeprops= {'edgecolor': 'white'}  )
 plt.title(f"Distribution of {i}")
 plt.show()

# %% [markdown]
# ---
#
# ### **Documentation: Categorical Feature Distribution Using Pie Charts**
#
# #### **1. Sex Distribution 👫**
#
#
# | **Category** | **Percentage** |
# |--------------|----------------|
# | Males        | 50.5%          |
# |
# | Females      | 49.5%          |
# |              |                |
#
# **Insight* : The dataset has nearly equal gender distribution, ensuring balanced representation.
#
# ---
#
# #### **2. Children Distribution 👶🏻**
#
#
# | **Category**       | **Percentage** |
# |--------------------|----------------|
# | No Children        | 42.8%          |
# |
# | One Child          | 24.3%          |
# |
# | Two to Five Children | 14.0%.       |
# |                    |
#
# *Insight* : Most individuals have zero or one child, which could influence analyses related to family size.
#
# ---
#
# #### **3. Smoker Distribution 🚭💨**
#
# | **Category** | **Percentage** |
# |--------------|----------------|
# | Non-smokers  | 79.5%          |
# |
# | Smokers      | 20.5%          |
#
# *Insight* : A significant majority are non-smokers, which could impact health-related analysis.
#
# ---
#
# #### **4. Region Distribution 🌍**
#
# | **Region**   | **Percentage** |
# |--------------|----------------|
# | Southeast    | 27.3%          |
# |
# | Northwest    | 24%            |
# |
# | Northeast    | 24%            |
# |
# | Southwest    | 24%            |
#
# *Insight*: The dataset is fairly balanced across regions, supporting region-based analysis.
#
# ---

# %% [markdown]
# 2. **Plotting a Bar Chart for Each Categorical Column with the Target Variable**
#
# - Bar charts are used for each categorical column to compare the distribution within each category
#
#  against the target (e.g., smoking status), making it easier to see category-based differences.

# %%
Gender = pd.crosstab(data['sex'] , data['smoker'])
Gender.plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ---
#
# ### **Insights: Smoking Status vs Sex**
#
# - **Higher Proportion of Non-smokers**: The number of non-smokers is greater than smokers.
# - **Female Non-smokers**: There are more female non-smokers than male non-smokers.
# - **Male Smokers**: The number of male smokers exceeds female smokers.
#
# ---

# %%
Zone = pd.crosstab(data['region'] , data['smoker'])
Zone.plot(kind='bar')
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# ### **Insights: Smoking Status by Region**
#
# - **Southwest Region**: The highest number of smokers is found in the southwest region.
# - **Northeast Region**: The highest number of non-smokers is in the northeast region.
#
# ---

# %%
kids = pd.crosstab(data['children'] , data['smoker'])
kids.plot(kind = 'bar')
# Out:
# <Axes: xlabel='children'>

# %% [markdown]
# ---
#
# ### **Insights: Relationship Between Number of Children and Smoking Status**
#
# #### **Key Observations**:
#
# - **Non-smokers with 0 Children** :
#
#   The highest count of **non-smokers** is found in individuals with **0 children**.
#
# - **Decrease in Smokers with More Children** :
#
#   The number of **smokers** decreases as the number of children increases.
#
#   This indicates that individuals with more children may be less likely to smoke.
#
# ---
#
# #### **Overall Interpretation**:
#
# - **Trend of Reduced Smoking**:
#
#   The chart suggests a **possible trend** where individuals with more children are less likely to smoke compared to those with fewer or no children.
#
# - **Caution About Correlation**:
#
#   The chart shows a trend suggesting that
#
#   **non-smokers** are more common among individuals with 0 children
#
#   and **smokers** are less common as the number of children increases.
#
#   However, further analysis is required to confirm a direct cause-and-effect relationship.
#
# ---

# %% [markdown]
# 3. **Plotting a Bar Chart for `children` and `charges` Based on Smoking Status**
#
# - This bar chart visualizes the distribution of insurance charges (`charges`) by the number of children
#
#  and smoking status, making trends or patterns in these variables easier to identify.

# %%
sns.barplot(data = data , x = 'children' , y = 'charges' , hue='smoker')
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %% [markdown]
# ### **Insights: Insurance Charges by Number of Children and Smoking Status**
#
#
# #### **Overall Interpretation** :
#
# - **Trend of Higher Charges for Smokers with Children**:
#
#   The data indicates that **insurance charges** are typically higher for individuals who smoke
#
#    especially those with more children.
#
# - **Correlation Between Smoking, Children, and Charges** :
#
#   There is a clear trend that both **smoking status** and the **number of children**
#
#   play a role in determining insurance charges.
#
#
#     Further analysis would be needed to understand the exact relationship and whether it directly impacts the charges.
#
# ---

# %% [markdown]
# # Encoding
#
# ❐ **Objective**: Convert categorical columns into a suitable numerical format to enhance model performance.
#
# ❐ **Purpose**: Improve the performance of the data analysis model by representing categorical values as numbers.

# %%
cat.columns
# Out:
# Index(['sex', 'children', 'smoker', 'region'], dtype='object')

# %% [markdown]
# ## Encoding Type Used
#
#
# **Label Encoding**
#
#     We will use Label Encoding to transform categorical values into numerical representations
#     facilitating better understanding by machine learning models.
#
# ### Targeted Columns
#
# **sex**
#
# **children**
#
# **smoker**
#
# **region**

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

for column in cat.columns:
  data[column] = LE.fit_transform(data[column])

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1335 rows x 7 columns]

# %% [markdown]
# ---
#
# ### Conclusion of Encoding Step
#
# - Successfully transformed categorical features into numerical values.
# - Changes were verified in the original dataset, preparing for the next step (scaling).
#
# ---

# %% [markdown]
# # Scaling
#
#
# ❐ Scaling procedure for data to improve the performance of statistical models and machine learning
#
# by standardizing the range of values, enhancing accuracy and efficiency in analysis

# %% [markdown]
# ##**Method Used:**
# - **Z-Score Scaling**, which transforms values into standardized values (Z-scores) so that the mean is 0 and the standard deviation is 1.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

data = pd.DataFrame(data_scaled, columns=data.columns)

# %%
data
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0    -1.438258 -1.009786 -0.452785 -0.910479  1.967807  1.345989  0.297300
# 1    -1.509472  0.990309  0.509707 -0.080793 -0.508180  0.440296 -0.954047
# 2    -0.797331  0.990309  0.383452  1.578578 -0.508180  0.440296 -0.729199
# 3    -0.441261  0.990309 -1.304598 -0.910479 -0.508180 -0.465397  0.718247
# 4    -0.512475  0.990309 -0.292096 -0.910479 -0.508180 -0.465397 -0.777291
# ...        ...       ...       ...       ...       ...       ...       ...
# 1330  0.769379  0.990309  0.050597  1.578578 -0.508180 -0.465397 -0.221451
# 1331 -1.509472 -1.009786  0.206366 -0.910479 -0.508180 -1.371090 -0.914390
# 1332 -1.509472 -1.009786  1.014728 -0.910479 -0.508180  0.440296 -0.961948
# 1333 -1.295830 -1.009786 -0.797118 -0.910479 -0.508180  1.345989 -0.930737
# 1334  1.552734 -1.009786 -0.260942 -0.910479  1.967807 -0.465397  1.309020
#
# [1335 rows x 7 columns]

# %% [markdown]
# # **Final Documentation of Data Processing**
#
# After completing the data processing steps, it has been confirmed that the dataset is now ready for modeling purposes.
#
# **Completed Steps :**
#
# 1. **Data Verification :**
#    - The columns in the dataset were reviewed to ensure there are no non-numeric values.
#    - Textual columns were encoded, making all values numeric.
#
# 2. **Scaling :**
#    - **Z-Score Scaling** was applied to all numerical columns.
#    - The results showed a balanced distribution with both negative and positive values, indicating that all features are now on the same scale.
#
# 3. **Verification Results :**
#    - All values were verified to fall within an appropriate range
#    - Our data is now clean and logical, facilitating future analyses.
#
# **Conclusion :**
#
# After performing all necessary steps, the dataset is prepared for the next phase, which is **modeling**.
#
# We are confident that this data will contribute to achieving accurate and reliable results in future analyses.
